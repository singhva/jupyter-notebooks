# %%
import os, sys, re, glob
from pymongo import MongoClient
from com.ibm.watson.datasource.clinicaltrials import ClinicalStudy
from com.ibm.watson.datasource.concepts import get_concepts
import numpy as np
import pandas as pd
from com.ibm.watson.datasource.wga_dev_db import get_wga_drug_df
import datetime
from collections import OrderedDict
from bson.codec_options import CodecOptions
from bson.son import SON

# %%
levels = [ ["NCT02407054", "NCT02407054", "NCT02962401"], ["Drug A", "Drug B", "Drug C"] ]
tuples = list(zip(*levels))
index = pd.MultiIndex.from_tuples(tuples, names=['NCT_ID', 'Drug'])
s = pd.DataFrame( ["AA", "BB", "CC"] , index=index, columns=["RAN"])
print tuples
print index
print s
s.to_excel("/Users/singhv/Desktop/new_drug.xlsx")
# Out:
# [('NCT02407054', 'Drug A'), ('NCT02407054', 'Drug B'), ('NCT02962401', 'Drug C')]
# MultiIndex(levels=[[u'NCT02407054', u'NCT02962401'], [u'Drug A', u'Drug B', u'Drug C']],
#            labels=[[0, 0, 1], [0, 1, 2]],
#            names=[u'NCT_ID', u'Drug'])
#                    RAN
# NCT_ID      Drug
# NCT02407054 Drug A  AA
#             Drug B  BB
# NCT02962401 Drug C  CC

# %%
client = MongoClient()
db = client.WATSON
opts = CodecOptions(document_class=SON)
ctgov = db.CTGOV.with_options(codec_options=opts)
base_dir = os.path.join("/Users/singhv/Documents/Data/CTGOV/latest")

# %%
#cs = ClinicalStudy()
#cs.load_from_file(os.path.join(base_dir, "xmls", "update", "NCT02953782.xml"))
#print cs.get_trial_id()
relevant_drugs = pd.read_excel("/Users/singhv/Desktop/trial_stats/Drugs_to_query_for_trials_MODIFIED.xlsx", 
                            converters={'Therapy_ID': str})
print relevant_drugs [ relevant_drugs['Therapy_ID'] == '5168' ]
# Out:
#    Therapy_ID     Therapy in Quest priory list NCI_CODE  NCIM_CUI  UMLS_CUI
# 27       5168  Danusertib                  NaN   C61587  C2700603  C2700603

# %%
print relevant_drugs [ relevant_drugs['UMLS_CUI'] == 'C0393022' ].any()['UMLS_CUI']
# Out:
# False

# %%
new_drugs_dict = dict()
df_indices = []
umls_concepts = []
relevant_drug_exists = []
for count, xml in enumerate(glob.glob1(os.path.join(base_dir, "xmls", "update.old"), "*.xml")):
    if (count % 10 == 0):
        print "Processed %d (%s)" % (count, xml)
    cs = ClinicalStudy()
    try:
        cs.load_from_file(os.path.join(base_dir,"xmls", "update.old", xml))
        nct_id = cs.get_trial_id()
        interventions = cs.get_interventions()
        drug_names = interventions.get("Drug", [])
        db_trial = db.CTGOV.find_one({"NCT_ID" : nct_id})
        existing_interventions = db_trial["interventions"]
        existing_drug_names = [ x["NAME"] for x in existing_interventions ]
        non_existing_drugs = set(drug_names) - set(existing_drug_names)
        df_indices.extend( [(nct_id, drug_name) for drug_name in non_existing_drugs] )
        for drug_name in non_existing_drugs:
            concept = get_concepts(drug_name)
            if concept:
                umls_cui = concept[0]["UMLS_CUI"]
                umls_concepts.append(umls_cui)
                relevant_drug_exists.append("Y" if relevant_drugs[ relevant_drugs["UMLS_CUI"] == umls_cui ].any()['UMLS_CUI'] else "N" )
            else:
                umls_concepts.append("NONE")
                relevant_drug_exists.append("N")
    except:
        print "Exception processing: %s" % xml
            

print df_indices
index = pd.MultiIndex.from_tuples(df_indices, names=['NCT_ID', 'Drug'])
df = pd.DataFrame({"UMLS_CUI" : umls_concepts, "EXISTS" : relevant_drug_exists}, index=index)
print df

# %%
print df.loc[(u'NCT00047060', u'Campath-1H')]
nct_cache = {}
for (nct_id, drug) in df.index.values:
    status = nct_cache.get(nct_id, db.CTGOV.find_one({"NCT_ID" : nct_id})["metadata"]["STATUS"])
    nct_cache[nct_id] = status
    df["STATUS"][(nct_id, drug)] = status
    
print df.head(10)

# %%
df.to_excel("/Users/singhv/Desktop/trial_stats/all_inscope_drug_trials.xlsx")

# %%
df = pd.read_excel("/Users/singhv/Desktop/trial_stats/all_inscope_drug_trials.xlsx", index_col=[0,1])

# %%
# Reshaped dataframe with trial id in every row
new_index_column = list()
for (trial_id, drug_name) in df.index.values:
    new_index_column.append(trial_id)
    
df["NEW_NCT_ID"] = new_index_column
df.to_excel("/Users/singhv/Desktop/trial_stats/all_inscope_drug_trials_reshaped.xlsx")

# %%
#indices = df[ (df["DRUG OF INTEREST"] == "Y") & (df["STATUS"] == "ACCEPTED") ].index.values
indices = df.index.values
trial_ids = set([ index[0] for index in indices ])
print len(trial_ids)
#print df.loc[(u'NCT01042379', )]
# Out:
# 2744

# %%
#print df.loc[(u'NCT01042379', )].shape
#for row in df.loc[(u'NCT01042379', )].itertuples():
#    print row[2]
inscope_trial_ids = set( [x[0] for x in df [ df["DRUG OF INTEREST"] == "Y" ].index] )
#print df [ df["DRUG OF INTEREST"] == "Y" ].index[0]
print len(inscope_trial_ids)
print db.CTGOV.find({"NCT_ID" : {"$in" : list(inscope_trial_ids)}, "metadata.STATUS" : "PENDING"}).count()
#update = db.CTGOV.update_many({"NCT_ID" : {"$in" : list(inscope_trial_ids)}, "metadata.STATUS" : "PENDING"}, {"$set" : {"metadata.STATUS" : "ACCEPTED"}})

#print update.modified_count
# Out:
# 535
# 0

# %%
for i, trial_id in enumerate(trial_ids):
    if i % 500 == 0: 
        print "Processed %d" % i
    study = db.CTGOV.find_one({"NCT_ID" : trial_id})
    existing_drug_names = set([ x["NAME"] for x in study["interventions"] ])
    new_status = "PENDING" if (study["metadata"]["STATUS"] == "ACCEPTED") else study["metadata"]["STATUS"]
    interventions = list()
    for row in df.loc[(trial_id, )].itertuples():    
        if not (row[0] in existing_drug_names):
            intervention = [ ("ID", row[2]), ("NAME", row[0]), ("PREFERRED_NAME", get_preferred_term(row[2])),
                           ("SOURCE", "ctm"), ("TYPE", "Drug"), ("EDIT", False) ]
            interventions.append(OrderedDict(intervention))
    db.CTGOV.update_one({"NCT_ID" : trial_id}, 
                        {"$push" : {"interventions" : {"$each" : interventions}},
                         "$set" : {"metadata.STATUS" : new_status, "metadata.UPDATED_BY" : "SYSTEM",
                                  "metadata.LAST_UPDATED" : datetime.datetime.utcnow()}})
# Out:
# Processed 0
# Processed 500
# Processed 1000
# Processed 1500
# Processed 2000
# Processed 2500
# Processed 3000
# Processed 3500
# Processed 4000
# Processed 4500
# Processed 5000

# %%
wga_drug_df = get_wga_drug_df()
result = wga_drug_df[ wga_drug_df['UMLS_CUI'] == "C0210630" ]
print result["THERAPY_ID"]
# Out:
# Series([], Name: THERAPY_ID, dtype: object)

# %%
# Updating trials with CL CUIs replace with UMLS CUIs
#wga_drug_df = get_wga_drug_df()
#print wga_drug_df.head(2)
count = 0
for study in db.CTGOV.find({"$query": {}, "$snapshot" : True}):
    for intervention in study["interventions"]:
        cui = intervention.get("ID")
        umls_cui = None
        wgadb_id = intervention.get("WGADB_ID")
        if (cui is not None) and (cui != ""):
            if "CL" in cui:
                nci_record = db.NCIT.find_one({"NCIM_CUI" : cui})
                if nci_record and nci_record.get("UMLS_CUI"):
                    intervention["ID"] = nci_record.get("UMLS_CUI")
                    umls_cui = nci_record.get("UMLS_CUI")
            else:
                umls_cui = cui
            if (wgadb_id is None) and (umls_cui is not None):
                result = wga_drug_df[ wga_drug_df["UMLS_CUI"] == umls_cui ]
                if result["THERAPY_ID"].any():
                    intervention["WGADB_ID"] = result["THERAPY_ID"].any()
                    
    db.CTGOV.save(study)
    #count += db.CTGOV.save(study)["nModified"]
    #print "Current count: %d" % count
    
#print "Count: %d" % count

# %%
def merge_interventions(int1, int2):
    curated = int1 if "EDIT" in int2 else int2
    latest = int1 if "EDIT" in int1 else int2
    curated["NAME"] = latest["NAME"]
    curated["EDIT"] = False
    return curated

# %%
# UPdating trials to merge interventions which only differ due to case
unchanged_trials = list()
changed_trials = list()
count = 0
for study in db.CTGOV.find({"$query": {"metadata.STATUS":"PENDING"}, "$snapshot" : True}):
#for study in ctgov.find({"$query": {"NCT_ID":"NCT01951885"}, "$snapshot" : True}):
    curated_interventions = [ x for x in study["interventions"] if "EDIT" not in x ]
    interventions = sorted( study["interventions"], key=lambda x: x["NAME"].lower() )
    #print "\n".join([ x["NAME"] for x in interventions ])
    new_intervention_array = []
    i = 0
    while ( i < len(interventions) ):
        if i < (len(interventions) - 1):
            if interventions[i]["NAME"].lower() == interventions[i + 1]["NAME"].lower():
                new_intervention_array.append(merge_interventions(interventions[i], interventions[i + 1]))
                i += 2
            else:
                new_intervention_array.append(interventions[i])
                i += 1
        else:
            new_intervention_array.append(interventions[i])
            i += 1
    for intervention in new_intervention_array:
        if "ID" in intervention and (intervention.get("PREFERRED_NAME") == ""):
            record = db.NCIT.find_one({"UMLS_CUI" : intervention["ID"]})
            if record:
                intervention["PREFERRED_NAME"] = record["PREF_NAME"]
    if len(curated_interventions) == len(new_intervention_array):
        count += ctgov.update_one({"NCT_ID":study["NCT_ID"]},{"$set" : {"interventions" : new_intervention_array, "metadata.STATUS" : "ACCEPTED"}}).matched_count
        print "Same length: %s" % study["NCT_ID"]
    else:
        count += ctgov.update_one({"NCT_ID":study["NCT_ID"]},{"$set" : {"interventions" : new_intervention_array}}).matched_count
    
print
#print "\n".join([ x["NAME"] for x in new_intervention_array ])
#print len(new_intervention_array)
print "Updated: %d" % count
# Out:
# Updated: 1376

# %%
#Updating all trials to add EDIT in interventions
count = 0
for study in ctgov.find({"$query": {}, "$snapshot" : True}):
    new_intervention_array = []
    for intervention in study["interventions"]:
        if "EDIT" not in intervention:
            intervention["EDIT"] = True
        new_intervention_array.append(intervention)
        
    count += ctgov.update_one({"NCT_ID":study["NCT_ID"]},{"$set" : {"interventions" : new_intervention_array}}).matched_count
    
print "Total updated: %d" % count
# Out:
# Total updated: 6749

# %%
# Setting all PENDING trials with in-scope drugs to ACCEPTED
pending_trials = []
for trial in db.CTGOV.find({"metadata.STATUS" : "PENDING"}):
    drug_umls_cuis = [ therapy["ID"] for therapy in trial["interventions"] if "ID" in therapy ]
    if relevant_drugs['UMLS_CUI'].isin(drug_umls_cuis).any():
        pending_trials.append(trial["NCT_ID"])
        
print len(pending_trials)
# Out:
# 267

# %%
client_prod = MongoClient("bioresearch-d1:23001")
db_prod = client_prod["WATSON"]
trials_with_inscope_drugs = []
for trial in db_prod.CTGOV.find({"COUNTRIES":"United States"}):
    drug_umls_cuis = [ therapy["ID"] for therapy in trial["interventions"] if "ID" in therapy ]
    if relevant_drugs['UMLS_CUI'].isin(drug_umls_cuis).any():
        trials_with_inscope_drugs.append(trial["NCT_ID"])
        
print len(trials_with_inscope_drugs)
# Out:
# 1458

# %%
print len(trials_with_inscope_drugs)
print trials_with_inscope_drugs[:10]
temp = db_prod["CTGOV"].find({"NCT_ID" : {"$in" : trials_with_inscope_drugs},"metadata.DOWNLOAD_DATE" : {"$gt" : datetime.datetime(2017,3,27,0,0)}})
print temp.count()
# Out:
# 1458
# [u'NCT02206763', u'NCT02610075', u'NCT02576444', u'NCT02413853', u'NCT02457793', u'NCT01548144', u'NCT02389309', u'NCT01884740', u'NCT01532011', u'NCT02155920']
# 14

# %%
print db_prod.CTGOV.update_many({"NCT_ID" : {"$in" : trials_with_inscope_drugs}}, {"$set":{"metadata.REVIEWER":"pmcneil"}}).modified_count
# Out:
# 14

# %%
result = wga_drug_df["THERAPY_ID"][ wga_drug_df['UMLS_CUI'] == "C3661275" ]
if result.any():
    print "ha"

# %%
count = 0
count1 = 0
for study in db.CTGOV.find({"interventions.WGADB_ID" : {"$ne" : True}}):
    #temp = [ x for x in study["interventions"] if "WGADB_ID" not in x ]
    #count += len(temp)
    print study["NCT_ID"]
    for intervention in study["interventions"]:
        if ("WGADB_ID" not in intervention):
            count += 1
            print "\t" + intervention.get("ID", "") 
            result = wga_drug_df["THERAPY_ID"][ wga_drug_df['UMLS_CUI'] == intervention.get("ID") ]
            if result.any(): count1 += 1
    
print "Count is: %d" % count
print "Count1 is: %d" % count1

# %%
no_interventions = [ x["NCT_ID"] for x in db.CTGOV.find({"metadata.STATUS" : "ACCEPTED", "interventions" : {"$size" : 0}}) ]
no_conditions = [ x["NCT_ID"] for x in db.CTGOV.find({"metadata.STATUS" : "ACCEPTED", "conditions" : {"$size" : 0}}) ]

interventions_no_id = [ x["NCT_ID"] for x in db.CTGOV.find({"metadata.STATUS" : "ACCEPTED", "interventions.ID" : {"$exists" : False}}) ] 
conditions_no_id = [ x["NCT_ID"] for x in db.CTGOV.find({"metadata.STATUS" : "ACCEPTED", "conditions.ID" : {"$exists" : False}}) ]

no_interventions = set(no_interventions)
no_conditions = set(no_conditions)
interventions_no_id = set(interventions_no_id)
conditions_no_id = set(conditions_no_id)

# %%
print "Length no interventions: %d" % len(no_interventions)
print "Length no conditions: %d" % len(no_conditions)
print "Length interventions no id: %d" % len(interventions_no_id)
print "Length conditions no id: %d" % len(conditions_no_id)
print no_interventions.issubset(no_conditions)
print interventions_no_id.issubset(no_interventions)
print conditions_no_id.issubset(no_conditions)
print len(no_conditions.union(no_interventions))
# Out:
# Length no interventions: 14
# Length no conditions: 69
# Length interventions no id: 14
# Length conditions no id: 69
# False
# True
# True
# 71

# %%
genes = "erbb2|her2|alk|ros|ros1|ret|braf|mek|akt1|pi3k|pi3kca|mtor|abl1|abl|pdgfr|pdgfra|pdgfrb|kit|myc|met|jak"
genes = genes + "|egfr|fgfr|vegfr"
genes = genes + "|" + genes.upper()
expression = "pos|neg|positive|negative|expressed|expression|\+|\-"
#genes = "CML|AML"
#print genes
genes_regex = re.compile("(\w+\s\w+\s|\w+\W+)(%s)(\s*\w+\s*\w+|\w+\W+)" % (genes))
expr_regex = re.compile(expression, flags=re.IGNORECASE)
nct_ids, phrases = ([], [])
for study in db.CTGOV.find({}):
    inclusion = study["inclusion"].get("text", "")
    match = genes_regex.findall(inclusion)
    if match:
        for m in match:
            phrase = m[0] + m[1] + m[2]
            if expr_regex.search(phrase):
                print study["NCT_ID"] + ": " + phrase
                nct_ids.append(study["NCT_ID"])
                phrases.append(phrase)
                
output_df = pd.DataFrame(index=nct_ids)              
#output_df["NCT_ID"] = nct_ids
output_df["PHRASE"] = phrases
output_df.to_excel("/Users/singhv/Desktop/gene_expression_phrases.xlsx")
# Out:
# NCT01956669: 131 -
#              meta-
# NCT01738139: c-KIT mutations by
# NCT02412722: postovulation methods
# NCT02412722: postovulation methods for
# NCT01975701: translocation to FGFR1-
# NCT01975701: TACC1, FGFR3-
# NCT01787500: with positive BRAF V600 mutation
# NCT02091141: abnormalities:
#
#           -  HER2 overexpression
# NCT02091141: that have HER2 overexpression
# NCT02091141: Vemurafenib
#
#           -  BRAF mutation positivity
# NCT02438722: non-metastatic disease
# NCT01723202: post ovulation methods
# NCT01519323: Positive BRAF mutation result
# NCT01776008: and HER2 negative
# NCT01787487: BCR-ABL1 negative
# NCT02448771: required.
#
#           -  HER2 negative
# NCT02448771: negative (HER2 copy
#              number
# NCT01933815: cis-retinoic
#                   acid
# NCT02047214: cis-retinoic
#                   acid
# NCT02143414: BCR-ABL status must
# NCT01352520: CD30+ mycosis fungoides
# NCT01441947: and HER2 negative breast
# NCT01868022: FGF2 or FGFR1 expression
# NCT01792050: HER2)-, metastatic breast
# NCT02457910: 1b: HER2 negative
# NCT02457910: cells), HER2 negative
# NCT02301143: Non- metastasis
# NCT01035463: ALCL, alk neg
# NCT01931163: 4. HER2 negative tumors
# NCT02025881: c-myc or N
# NCT02028364: ER+), HER2
#              negative breast
# NCT02258451: and HER2 negative adenocarcinoma
# NCT00823459: cis-retinoic acid
# NCT00515411: 3+) metastatic or
# NCT00515411: are considered HER2 positive irrespective
# NCT01958658: positive or metastatic
# NCT02115464: Non-metastatic disease
# NCT00585195: c-MET and ROS
# NCT01744652: c-MET abnormality
# NCT01744652: c-MET amplification by
# NCT01744652: c-MET mutation
# NCT02134912: have documented ALK positivity at
# NCT02096588: chemotherapy. HER2 positive patients
# NCT02390843: I131-meta-
# NCT02123823: negative for HER2 per local
# NCT02128425: non-metastatic disease
# NCT02166242: EGFR/ALK mutation negative
# NCT02186821: laboratory. ALK positivity as
# NCT02187991: as:
#
#                -  HER2 negative status
# NCT00670358: double-method contraception
# NCT02213913: C-myc and BCL2
# NCT02213913: C-myc breaks
# NCT01791478: and HER2 negative
# NCT01746849: c-kit mutations
# NCT02236000: anti-HER2 based therapy
# NCT01639508: iii. MET overexpression
# NCT02311998: BCR-ABL positive
# NCT02296112: melanoma
#
#           -  BRAF mutation in
# NCT01750918: anti-EGFR therapy
# NCT01750918: anti-EGFR therapy must
# NCT01750918: anti-EGFR combo after
# NCT01750918: anti-EGFR therapy is
# NCT02034110: 2.
#
#           -  BRAF V600E mutation
# NCT02164916: EGFR
#
#                -  BRAF inhibitor including
# NCT01434472: v-myc myelocytomatosis
#              viral
# NCT01627041: PML)-retinoic acid
# NCT01386385: anti-retroviral therapy
# NCT01853748: required
#
#           -  HER2 positive
# NCT01982448: must be HER2 negative defined
# NCT01937117: IHC and HER2 positive
# NCT02484404: CRITERIA - METASTATIC CASTRATE
# NCT02292758: Evidence of EGFR expression in
# NCT00700882: c-KIT mutation identified
# NCT01593254: BCR-ABL reduction
# NCT01593254: BCR-ABL level
# NCT01593254: BCR-ABL detection
# NCT01850004: BCR-ABL
#                   transcript as
# NCT02181218: HL
#
#                -  mycosis fungoides
# NCT02203695: non-metastatic
# NCT02289833: classification.
#
#           -  HER2 status of
# NCT02052648: cis-retinoic acid
# NCT02179086: O6-methylguanin
# NCT02179086: DNA-methyltransferase
# NCT01923168: Patient has HER2 negative breast
# NCT02008383: anti-EGFR therapy
# NCT02032823: non-metastatic primary
# NCT02032823: negative AND HER2 negative
# NCT02032823: anti-HER2 therapy
# NCT02032823: positive, HER2 negative
# NCT01280565: c-kit JM mutation
# NCT02312557: has a metastatic deposit
# NCT02057133: negative metastatic breast
# NCT02057133: diagnosis of HER2 positive metastatic
# NCT02303951: Positive for BRAF V600 mutation
# NCT02312258: postovulation methods
# NCT02312258: postovulation methods for
# NCT02316028: chemotherapy
#
#           -  able to
# NCT02318329: determination of FGFR2b overexpression
# NCT02066532: HER2+ metastatic breast
# NCT01943422: classification).
#
#           -  BRAF V600E and
# NCT02088112: that is EGFR mutation positive
# NCT02088112: must be EGFR mutation positive
# NCT02338245: positive metastatic breast
# NCT01160211: Documentation of HER2 overexpression or
# NCT00812240: c-kit negative
#
#           4
# NCT01535053: non-metastatic choriocarcinoma
# NCT01723774: and HER2 negative
# NCT02158975: lymphoma (ALK
#              positive
# NCT02158975: lymphoma (ALK negative
# NCT02396108: Tumor is HER2 positive either
# NCT02398552: non-metastatic liver
# NCT02403193: or ALK rearrangement
#              positive
# NCT02180867: non-metastatic and
# NCT01406756: BCR-ABL1)
# NCT01231906: non-metastatic Ewing
# NCT01231906: non-metastatic
# NCT01231906: non-metastatic
# NCT01193842: v-myc avian myelocytomatosis
# NCT01193842: anti-retroviral therapy
# NCT02381548: Bcr)-ABL proto
# NCT01295944: cis-retinoic acid
# NCT01698905: BCR-ABL positive CML
# NCT02323126: or EGFR T790M positivity
# NCT02343536: c-MYC by IHC
# NCT02411344: and HER2 positivity
# NCT02423343: O6-methylguanine
# NCT00788307: Negative radiographic metastatic work
# NCT01434602: cis-retinoic acid
# NCT02045446: EML4-ALK positive NSCLC
# NCT02101385: positive. HER2 will be
# NCT02258464: and HER2 negative adenocarcinoma
# NCT00363649: BCR-ABL
#              rearrangement by
# NCT00363649: BCR-ABL fusion gene
# NCT00363649: BCR-ABL hybrid mRNA
# NCT02048371: advanced/metastatic
#              liposarcoma
# NCT02447419: scan + EGFR IHC overexpression
# NCT01666730: non-metastatic disease
# NCT02015104: negative for metastatic disease
# NCT02124902: allowed.
#
#           -  HER2 negative by
# NCT02309177: HER2(-) metastatic breast
# NCT02201992: EML4]-ALK fusion
# NCT01368588: negative for metastasis
# NCT01774786: positive metastatic adenocarcinoma
# NCT02464228: ALCL), ALK positive
#
#                2
# NCT02464228: ALCL, ALK negative
#
#                3
# NCT02128906: anti-retroviral therapy
# NCT02128906: anti-retroviral therapy
# NCT02205398: c-MET positive
# NCT02205398: c-MET IHC intensity
# NCT01196390: ONLY)
#
#           -  HER2 expressing adenocarcinoma
# NCT01966471: Non-metastatic histologically
# NCT01966471: node-metastasis staging
# NCT01966471: lesions are HER2 positive
# NCT01808573: Documented HER2 overexpression or
# NCT02445391: 2)
#
#                -  HER2 negative
# NCT02445391: anti-HER2 therapy
# NCT02486601: pylorus)
#
#           -  HER2 negative tumors
# NCT02488564: cancer
#
#           -  HER2 overexpressing cancer
# NCT02489448: PR and HER2 negative
#              invasive
# NCT02613650: KRAS positive metastatic colorectal
# NCT02427841: non-metastatic
# NCT00996567: treatment
#
#           -  EGFR IHC
# NCT02227940: positivity; ALK positivity can
# NCT02227940: of ALK positivity using
# NCT02227940: test for ALK positivity using
# NCT02227940: a confirmed ALK positivity
# NCT00206518: and
#
#                -  alkaline phosphatase
# NCT01674140: staining
#
#                -  HER2 test result
# NCT01674140: both.
#
#         HER2 is negative
# NCT01674140: 1+.
#
#         HER2 equivocal is
# NCT01674140: anti-retroviral therapy
# NCT01949337: non-metastatic
# NCT02496663: positive for EGFR T790M by
# NCT02499367: and HER2 negativity on
# NCT02499614: positive for ROS1 translocation
# NCT02500199: or HER2 overexpression
# NCT02500199: Patients with HER2 positive metastatic
# NCT02500199: anti-HER2 therapies for
# NCT02500199: Patients with HER2 positive metastatic
# NCT02500199: Patients with HER2 positive metastatic
# NCT02500199: anti-HER2 therapies for
# NCT01324479: c-MET dysregulation from
# NCT01324479: c-MET expression
# NCT01324479: c-MET positivity
# NCT01328171: non-metastatic disease
# NCT01373710: breast
#
#           -  HER2 Overexpression by
# NCT01413828: must be HER2 positive
# NCT01491737: positive advanced metastatic or
# NCT01203722: DNA-methyltransferase
#                        inhibitor
# NCT01707004: BCR-ABL positive diseases
# NCT02494882: BCR-ABL1 transcripts
# NCT02494882: bcr-abl TKI plus
# NCT02366130: anti-HER2 targeting therapy
# NCT01755767: therapy
#
#           -  MET Diagnostic
# NCT02512237: results are HER2 ISH positive
# NCT02529553: alterations of FGFR3.
#
#           -
# NCT02535507: cytologic confirmed HER2 positive advanced
# NCT02544997: assay
#              EGFR expression high
# NCT01652976: non-metastatic disease
# NCT00790842: double-method contraception
# NCT02004275: anti-retroviral therapy
# NCT02401542: to demonstrate FGFR3 positive
# NCT02091960: anti-HER2 agent as
# NCT02091960: anti-HER2 regimen was
# NCT02311933: and HER2 negative
# NCT02311933: positive and HER2 negative
# NCT02311933: staining
#
#           -  HER2 negative disease
# NCT02549430: 10%
#
#           -  HER2 negative breast
# NCT02551055: postovulation methods
# NCT02551055: postovulation
#                   methods for
# NCT02560298: anti-retroviral therapy
# NCT01690325: lesion
#
#           -  HER2 positive disease
# NCT01690325: or
#
#           -  HER2 negative disease
# NCT01690702: positive, HER2 negative
# NCT01692678: advanced or metastatic liposarcoma
# NCT01693549: negative) metastatic breast
# NCT01922583: follows:
#
#                -  EGFR mutations in
# NCT01922583: T790M.
#
#                -  EGFR mutations in
# NCT01922583: mutations.
#
#                -  HER2 mutation in
# NCT01922583: ins).
#
#                -  BRAF mutation in
# NCT01922583: D594G).
#
#                -  ALK translocation resulting
# NCT01922583: TFG-ALK fusion as
# NCT01922583: Positive ALK results from
# NCT01922583: acceptable.
#
#                -  ROS1 translocation
# NCT01922583: CD74-ROS1 or
# NCT01922583: SLC34A2-ROS1,
# NCT01922583: etc.
#
#                -  RET translocation resulting
# NCT01922583: KIF5B-RET fusion
# NCT01560416: cancer
#
#           -  HER2 negative
# NCT02088684: HR+), HER2 negative breast
# NCT00573989: anti-EGFR inhibitors or
# NCT02047474: non-metastatic prostate
# NCT02315196: PgR/HER2
#              negative
# NCT00877110: or MYCN-
# NCT00999700: staining of EGFR expression and
# NCT01037790: ER positive metastatic breast
# NCT02575222: non-metastatic high
# NCT02006043: c-met expression on
# NCT02034981: levels
#
#           -  able to
# NCT01140568: cis-retinoic acid
# NCT02580448: ER(+) HER2 normal breast
# NCT02580448: ER(+) HER2 normal breast
# NCT02580448: IHC
#
#                -  HER2 normal is
# NCT02580448: ER(+)/HER2 normal tumors
# NCT02580448: ER (+)/HER2 normal tumors
# NCT02580448: ER(+)/HER2 normal tumors
# NCT02583542: Negative for HER2 with 0
# NCT02584634: must be ALK negative NSCLC
# NCT02584634: must be ALK positive NSCLC
# NCT02585388: 4. HER2 negative on
# NCT02046421: Patients with HER2 positive disease
# NCT02052193: postovulation methods
# NCT02076594: stomach
#
#           -  HER2 negative tumor
# NCT02086721: ent-metastasis
# NCT02098954: squamous
#
#           -  EGFR sensitive mutations
# NCT02102789: anti-EGFR or any
# NCT02546986: postovulation methods
# NCT01147016: negative for metastatic disease
# NCT01796197: cancer
#
#           -  HER2 positive breast
# NCT01364493: 3. HER2 positive tumour
# NCT01389583: c-kit or PDGFR
# NCT01410214: therapy.
#
#           -  EGFR activating mutation
# NCT02590952: criteria:
#
#           -  EGFR sensitizing mutation
# NCT02592785: High FGFR expression levels
# NCT02592785: low overall FGFR expression levels
# NCT02595866: c-ros oncogene 1
# NCT02595866: inhibitor if BRAF V600 positive
# NCT02598310: 4. HER2 positive confirmed
# NCT02599714: 5. HER2 negative
#
#           6
# NCT02122770: postovulation methods
# NCT02122770: postovulation methods for
# NCT02125344: cells, HER2 negative
# NCT02129257: ULN)
#
#                -  alkaline phosphatase
# NCT02129556: anti-HER2 therapy
# NCT02129556: confirmation of HER2
#              positivity and
# NCT02132598: c-MET Fluorescence in
# NCT02132598: c-MET amplification will
# NCT02144194: is HER2 neu negative
# NCT02252887: anti-HER2 agents
# NCT01938833: negative for HER2 expression
# NCT02393690: post-ablation
#              scans
# NCT01522768: cancer.
#
#           -  HER2 overexpression and
# NCT01661335: Doxorubicin + methotrexate 5
# NCT02605486: cancer.
#
#           -  HER2 normal
# NCT02606097: c-kit exon 17
# NCT02607072: nodal-metastasis
# NCT02610777: postovulation methods
# NCT02610777: postovulation methods for
# NCT00542191: and HER2 negative
#              invasive
# NCT00542191: Note: HER2 negative by
# NCT02214004: ml
#
#           -  HER2 positive tumor
# NCT01067066: cis-retinoic acid
# NCT01325207: CRITERIA
#
#           -  HER2 positive
# NCT01705002: anti-EGFR antibodies
# NCT01752569: anti-retroviral drug
# NCT01770353: PR and HER2 negative
# NCT01770353: PR and HER2
#              negative
# NCT02614794: to confirm HER2 positivity
# NCT02619435: anti-EGFR antibodies
#
#           3
# NCT02621333: EML4-ALK fuse gene
# NCT02621333: EML4-ALK is FISH
# NCT02286219: anti-HER2 directed therapies
# NCT02286219: anti-HER2 directed therapy
# NCT02286219: anti-HER2 directed therapy
# NCT02286219: anti-HER2 therapy if
# NCT02286219: anti-HER2 agent for
# NCT02286219: anti-HER2
#                   therapy is
# NCT00626990: O6-methylguanine
# NCT02437318: and has HER2 negative
#              breast
# NCT01772732: toxicity;
#
#           -  EGFR mutation positive
# NCT01785420: cancer: HER2 positive
# NCT01794845: negative for metastases
# NCT02630368: histologically confirmed HER2 negative breast
# NCT02302495: form
#
#           -  able to
# NCT02303899: C-kit by immunohistochemistry
# NCT02323113: postovulation methods
# NCT02323113: postovulation methods
#              for
# NCT02350530: non-metastatic disease
# NCT02176967: v-myc avian myelocytomatosis
# NCT02181413: postovulation methods for
# NCT02181413: postovulation methods for
# NCT02037529: Documentation of HER2 negative breast
# NCT01805271: and HER2 negative
# NCT01805271: tumor, HER2 negativity is
# NCT01805908: Tumour HER2 positive by
# NCT01813253: Subjects with EGFR overexpression
# NCT01828021: Evidence of HER2 oncoprotein expression
# NCT01830361: c-KIT mutated t
# NCT01830361: c-KIT gene
# NCT01830361: mut-KIT17 or
# NCT01830361: mut-KIT8)
# NCT01830361: c-KIT and FLT3
# NCT02650375: Cancer;
#
#           -  MET gene amplification
# NCT02650648: or MYCN-
# NCT02361112: cytologic confirmed HER2 positive metastatic
# NCT02374645: phase: EGFR mutation positive
# NCT02374645: phase: EGFR mutation positive
# NCT01424982: bcr-abl positive
# NCT01107626: anti-retroviral therapy
# NCT01316757: anti-retroviral therapy
# NCT01837095: edition).
#
#           -  HER2 negative
# NCT01850303: IV
#
#           -  EGFR wild type
# NCT01855828: guidelines.
#
#         HER2 overexpression or
# NCT01855854: Overexpression of EGFR defined by
# NCT02657343: be HER2 positive as
# NCT02657434: non-metastatic disease
# NCT02659514: Confirmed HER2 overexpression or
# NCT02664103: Cancer
#              (HER2 negative
# NCT02386826: c-MET gene copy
# NCT02416739: therapy
#
#           -  EGFR mutated
# NCT01911507: evidence of MET expression by
# NCT01911507: evidence of MET positivity and
# NCT01875367: cancer with HER2 positive histologically
# NCT01875367: for positivity HER2 are
# NCT01875367: positive for HER2 amplification
# NCT01877083: to be RET positive
# NCT01877083: KIF5B-RET translocation
# NCT01887288: anti-HER2 or hormonal
# NCT01887288: they have HER2 positive or
# NCT02674750: expression of MYC in
# NCT02679144: cis-retinoic acid
# NCT02679144: cis-retinoic acid
# NCT02422589: or ALK overexpression that
# NCT02423603: Negative for HER2 with 0
# NCT02423902: anti-HER2 therapy
#
#           6
# NCT02435108: c-MET positive gastric
# NCT02448420: Invasive HER2 positive breast
# NCT02448420: positive HER2 status must
# NCT02448420: anti-HER2
#              treatment in
# NCT02448420: anti-HER2 drugs
# NCT02450877: postovulation methods
# NCT02508077: anti-EGFR therapy
# NCT02508077: non-EGFR targeting regimen
# NCT02508077: anti-EGFR plus
#              irinotecan
# NCT02508077: anti-EGFR therapy prior
# NCT02508077: anti-EGFR therapy prior
# NCT02542124: CD4+ mycosis fungoides
# NCT01888081: negative for BRAF or have
# NCT01917279: negative metastatic breast
# NCT01918254: review
#
#           -  HER2 status confirmed
# NCT01935336: ISH) +, FGFR1 SISH
# NCT01935336: ISH+, FGFR1 SISH
# NCT02691299: Patients with ALK test negative
# NCT02691299: positive with ALK test result
# NCT02699073: anti-EGFR
#              therapy
# NCT02478164: anti-VEGFR or anti
# NCT00691379: No HER2 overexpression or
# NCT00911560: age), MYCN-
# NCT01391260: with tumor EGFR mutation positive
# NCT01397019: non-metastatic pancreatic
# NCT01962103: postovulation methods
# NCT01970865: patients (ALK positive and
# NCT01970865: NSCLC and ROS1-
# NCT01970865: setting.
#
#         ROS1-
# NCT01976741: to high FGFR expression levels
# NCT01976741: low overall FGFR
#              expression levels
# NCT01979276: vasectomy.
#
#           -  able to
# NCT01985087: o6-methylguanine
# NCT01985087: DNA-methyltransferase promoter
# NCT02712723: must be HER2 negative
# NCT02715531: Absence of HER2 expression documented
# NCT02715804: non-metastatic pancreatic
# NCT02725541: allowed);
#
#           -  HER2 low or
# NCT02725541: entry)
#
#                -  HER2 low expression
# NCT02725541: cell
#
#                -  HER2 equivocal expression
# NCT02726399: adenocarcinoma with HER2 overexpression
#              and
# NCT02726568: Positive EGFR mutation
# NCT02260661: positive, HER2
#              negative breast
# NCT02260661: positive, HER2
#              negative postmenopausal
# NCT02260661: positive, HER2 negative postmenopausal
# NCT02492711: anti-HER2 therapies are
# NCT02510001: c-MET assessment
# NCT01467986: and all MYCN
#         pos
# NCT02514031: for:
#
#                -  metastatic
# NCT02525653: ULN),
#
#           -  alkaline phosphatase
# NCT02525757: non-metastatic
# NCT02530411: confirmation of HER2 negative breast
# NCT01543802: Non-metastatic primary
# NCT01564056: IHC),
#
#           -  HER2 negative status
# NCT01596751: PR and HER2
#         negative disease
# NCT01600573: criteria
#
#           -  able to
# NCT01614301: allowed.
#
#           -  BRAF V600 mutation
# NCT01619111: positive. HER2 status
#                   must
# NCT01657604: BCR-ABL positive in
# NCT01670500: M0
#
#           -  HER2 negative
# NCT02532400: 7. HER2 negative
# NCT02540824: cytologic confirmed RET fusion positive
# NCT01677741: lesion.
#
#           -  BRAF V600 mutation
# NCT01683422: non-metastatic adenocarcinoma
# NCT01702571: anti-HER2 agent
# NCT01719549: chemotherapy.
#
#           -  FGFR2 amplification
# NCT01719835: ALCL) ALK negative cases
# NCT01737827: c-MET pathway dysregulation
# NCT01743131: BCR-ABL negative
# NCT01943851: overexpression of MYC and either
# NCT02000882: testing; HER2 negative status
# NCT02004769: 4. HER2 positive tumor
# NCT02013219: must be ALK positive
#              as
# NCT02024009: non-metastatic inoperable
# NCT02028507: Documented HER2 negative breast
# NCT02028507: biopsy. HER2 negative tumor
# NCT02030561: trastuzumab for HER2
#              positive breast
# NCT02035813: 4. HER2 negativity of
# NCT02063529: non-metastatic disease
# NCT02130466: MRI])
#
#           -  BRAF mutation
# NCT02143466: diagnosis of EGFRm+
# NCT02160353: barrier-method of
# NCT02202200: exposure to BRAF inhibitor or
# NCT02213042: Documentation of HER2 overexpression or
# NCT02214407: bcr-abl rearrangement
# NCT02238808: cancer
#
#           -  HER2 negative breast
# NCT02284139: reason
#
#                -  EGFR mutation
# NCT02285179: have either HER2 negative or
# NCT02319577: non-metastatic
# NCT02323178: bcr-abl rearrangement
# NCT02330783: non-metastatic liver
# NCT02769962: if liver mets)
#
#           -
# NCT02769962: if liver mets)
#
#           -
# NCT02737774: Positive EGFR mutation
# NCT02655536: exposure to EGFR inhibitors or
# NCT02655536: non-metastatic disease
# NCT02723877: cancer.
#
#           -  HER2 negative breast
# NCT02768415: women; HER2 negative
# NCT02383433: non-metastatic disease
# NCT02705859: Documented HER2 overexpression by
# NCT02398825: BCR-ABL1+
# NCT02398825: BCR-ABL1 >
# NCT02398825: BCR-ABL1 >
# NCT02398825: BCR-ABL1 bigger or
# NCT02398825: BCR-ABL1 mutation
# NCT02783222: status; HER2 receptor negative
# NCT02783222: OR HER2
#              positive but
# NCT02783222: anti-HER2 therapy
# NCT02829372: Progressive HER2 positive solid
# NCT02858921: response.
#
#           -  BRAF V600 mutation
# NCT02879695: anti-retroviral regimen
# NCT02868632: non-metastatic disease
# NCT02873195: anti-EGFR antibody
# NCT02862028: positive
#              EGFR family
# NCT02864992: therapy
#
#           -  MET Exon 14
# NCT01964391: non-metastatic primary
# NCT01964391: anti-HER2 therapy will
# NCT02882984: Positive EGFR mutation
# NCT02838420: or postovulation methods
# NCT02838420: postovulation methods
# NCT02884453: For HER2 positive tumours
# NCT02884453: c-MYC or HER2
# NCT02884453: c-MYC or
#              HER2
# NCT02873390: positive
#              EGFR family
# NCT02871791: negative metastatic breast
# NCT02910050: and HER2 negative breast
# NCT02961283: e.
#              BRAFV600 positive
# NCT02961283: or PI3K mutation positive
# NCT02961283: 1: BRAFV600 positive
# NCT02961283: 2: BRAFV600 positive
# NCT02511847: or without EGFR expression or
# NCT00327262: BCR-ABL positive CML
# NCT00327262: Ph+ metaphases in
# NCT01221870: disease
#
#           -  HER2 status negative
# NCT01795768: disease,
#
#           -  FGFR2 amplification
# NCT01795768: disease.
#
#           -  FGFR1 amplification
# NCT01795768: disease
#
#           -  FGFR1 amplification
# NCT00643825: Scan-methionine must
# NCT02465528: diagnosis of ALK positive
# NCT02194166: non-metastatic primary
# NCT02768207: Documentation of BRAF mutation positive
# NCT02752243: BCR-ABL positive leukemias
# NCT01126138: if
#              HER2 positive
# NCT00246727: non-metastatic non
# NCT00979641: years
#
#           -  able to
# NCT00506571: non-metastatic
# NCT02672475: cells, HER2 negative
# NCT02734004: negative metastatic breast
# NCT00687648: anti-retroviral therapy
# NCT01407822: CT.
#
#           -  EGFR activating mutation
# NCT01861197: chemotherapy
#
#           -  FGFR amplification
# NCT01980407: non-metastatic
# NCT01168050: c-KIT mutation or
# NCT01168050: C-KIT
#              amplification
# NCT02609503: non-metastatic
# NCT01307592: double-method contraception
# NCT02658981: 6-methylguanine
# NCT01732276: histologically proven EGFR positive metastatic
# NCT01782508: C-kit mutation documented
# NCT01227135: double-method contraception
# NCT02611492: BCR-ABL molecular maker
# NCT00411788: FISH +) metastatic breast
# NCT01609127: 4. HER2 negative disease
# NCT02630693: positive and HER2
#              negative status
# NCT01930864: anti-EGFR therapy
# NCT02760030: positive, HER2 negative breast
# NCT01995344: ULN
#
#           -  alkaline phosphatase
# NCT02447380: Patients with MET overexpression
#
#           7
# NCT02598427: 2+ HER2
#              patients are
# NCT00712140: Overexpression of HER2 receptor defined
# NCT00712140: 2+ HER2 positivity measured
# NCT00290485: confirmation of KIT overexpression must
# NCT02049489: dL
#
#                -  alkaline phosphatase
# NCT01354522: must be HER2 negative
# NCT02161679: triple negative metastatic breast
# NCT02145637: if ALK positive
# NCT02283476: non-metastatic tumor
# NCT01395121: c-KIT mutated histologically
# NCT02658084: ULN
#
#                -  alkaline phosphatase
# NCT02630420: Anti-EGFR
#              antibodies could
# NCT02770014: Adenosquamous
#
#           -  EGFR genotype must
# NCT00689195: non-metastatic disease
# NCT01195298: criteria;
#
#           -  HER2 negative disease
# NCT01276769: IHC), HER2 negativity is
# NCT00327678: BCR- ABL positive
# NCT00774319: non-metastatic locally
# NCT02716311: NSCLC
#
#           -  EGFR mutation
# NCT02651415: anti-EGFR therapy
# NCT02764541: PR),
#              HER2 negative
# NCT02764541: treated as HER2 negative
# NCT02261207: Expression of PDGFRB and
# NCT01005758: anti-metabolite therapy
# NCT02775903: postovulation methods
# NCT02775903: postovulation methods
# NCT00950365: anti-EGFR therapy for
# NCT02157051: IV HER2 negative breast
# NCT02706691: specifically FGFR1-
# NCT02706691: for:
#
#                -  FGFR1 amplification
# NCT02706691: amplification.
#
#                -  FGFR3 somatic
# NCT01566799: positive and HER2 negative
# NCT02522910: therapy.
#
#           -  EGFR mutated or
# NCT02769286: exposure to EGFR TKI
# NCT02619669: positive / HER2
#              negative
# NCT02807883: BCR-ABL transcript
#              by
# NCT02780401: non-metastatic
# NCT02780401: positive, HER2 negative breast
# NCT02780401: NED); HER2 negative is
# NCT02780401: 3+ HER2 expression by
# NCT01376505: has had EGFR expression measured
# NCT01376505: not had EGFR expression measured
# NCT01376505: determination of EGFR expression
# NCT02780778: cancer.
#
#           -  EGFR mutation testing
# NCT02790580: tumors is HER2 positive
# NCT02790580: non-metastatic
# NCT02790580: must be HER2 negative by
# NCT02810990: BCR-ABL1+
# NCT02810990: BCR-ABL1 >
# NCT02810990: BCR-ABL1 >
# NCT02810990: BCR-ABL1 >
# NCT02824133: expressing the FGFR3-
# NCT02824133: TACC3 or FGFR1-
# NCT02834247: postovulation methods
# NCT02834247: postovulation methods for
# NCT02520778: positive for EGFR T790M
# NCT01470716: cancer
#
#                -  EGFR exon 19
# NCT02800486: confirmed histologic EGFR overexpression
# NCT02860000: eligible); HER2 negative disease
# NCT02860000: following:
#
#                -  HER2 immunohistochemistry
# NCT02860000: amplified
#
#                -  HER2 IHC expression
# NCT02860000: done
#
#                -  HER2 IHC expression
# NCT02860000: ER+/HER2 negative invasive
# NCT02860000: ER+/HER2 negative
# NCT02860000: negative metastatic breast
# NCT02860000: ER+/HER2 negative invasive
# NCT02860000: ER+/HER2
#                   negative
# NCT02860000: purposes; metastatic or
# NCT02892734: lack of HER2
#              overexpression by
# NCT01932229: NSCLC
#
#           -  EGFR mutation or
# NCT02724020: postovulation methods
# NCT02724020: postovulation methods for
# NCT02664077: and
#
#                -  alkaline phosphatase
# NCT02861898: confirmed histologic EGFR overexpression
# NCT02844439: cis-retinoic acid
# NCT02885766: ULN;
#
#                -  alkaline phosphatase
# NCT02856997: lymphoma; ALK positive anaplastic
# NCT02856997: lymphoma; ALK negative anaplastic
# NCT02917005: 3. HER2 negative breast
# NCT02894398: disease (HER2 neg
# NCT02927249: positive, HER2 negative
# NCT02742051: non-metastatic unilateral
# NCT02852486: BCR-ABL in the
# NCT02836548: or BRAFi+
# NCT02836548: or BRAFi+
# NCT02836548: or BRAFi+
# NCT02844062: cells are EGFRvIII positive
# NCT02901301: 1. HER2 positive advanced
# NCT02912949: anti-HER2 or anti
# NCT02912949: anti-EGFR treatment
# NCT02725268: postovulation methods
# NCT00979160: symptoms.
#
#                -  KIT mutation status
# NCT02735239: B - metastatic
# NCT02743078: cis-retinoic acid
# NCT01728233: bleomycin-methotrexate
# NCT02927340: LDT).
#
#           -  ALK positive NSCLC
# NCT02927340: or postovulation methods
# NCT02965885: enrolled: HER2 positive MBC
# NCT02965885: NSCLC, EGFR T790M positive
# NCT02965885: NSCLC, EGFR T790M negative
# NCT02973737: cytologic confirmed HER2 positive advanced
# NCT02981303: and HER2 negative
# NCT02890784: BCR-ABL positive in
# NCT02897050: non-metastatic unilateral
# NCT01817751: who have PDGFRa-
# NCT01817751: only if PDGFRa-
# NCT02434081: ULN
#
#           -  alkaline phosphatase
# NCT02448797: Positive EGFR gene mutation
# NCT02689921: non-metastatic adenocarcinoma
# NCT02930954: naiive
#
#           -  EGFR exon 19
# NCT01931098: cis-retinoic acid
# NCT02668666: 1%), HER2 negative metastatic
# NCT02698189: bcr-abl tyrosine
# NCT02934529: anti-EGFR substance
# NCT02934529: anti-EGFR substance with
# NCT02934828: TNBC or HER2 positive breast
# NCT02935361: postovulation methods
# NCT02935361: postovulation methods
# NCT02939287: melphalan])
#
#           -  able to
# NCT02422199: cytologic confirmed HER2 positive advanced
# NCT02615574: anti-EGFR therapy
# NCT02684032: 2 (HER2 negative
# NCT02942095: anti-EGFR therapy
# NCT02942095: with positive EGFR T790M mutation
# NCT02942095: anti-EGFR therapy
# NCT02942095: anti-EGFR therapy
# NCT02942095: anti-EGFR therapy will
# NCT02942264: cis-retinoic acid
# NCT02942355: overexpression of HER2 by either
# NCT02942758: postovulation methods
# NCT02946359: positive for ROS1 translocation
# NCT02947386: L1 and EGFR
#              expression and
# NCT02947685: PR+), metastatic breast
# NCT02947685: report documenting HER2
#              positivity and
# NCT02947685: anti-HER2therapy and
# NCT02947685: anti-HER2 therapy to
# NCT02947685: anti-HER2 based induction
# NCT02344810: anti-MET therapy
# NCT02344810: determination of MET expression status
# NCT02344810: have had MET expression status
# NCT02313051: 1%, HER2 negative
# NCT02578511: postovulation methods
# NCT02578511: postovulation methods
# NCT02727777: postovulation methods
# NCT02727777: postovulation
#              methods for
# NCT02952573: results confirming FGFR3 expression
# NCT02953782: anti-EGFR antibody
# NCT02954406: postovulation methods
# NCT02954406: postovulation methods
# NCT02678975: possible to retest after
# NCT02503722: must be EGFR negative for
# NCT02169609: months)
#              MYCN-
# NCT02169609: or MYCN-
# NCT02673398: therapy
#
#           -  HER2 positivity as
# NCT02673398: If HER2 negative by
# NCT02657928: positive for retinoblastoma
# NCT02954536: adenocarcinoma with HER2
#              overexpression and
# NCT02955550: post ovulation methods
# NCT02956889: post ovulation methods
# NCT02958852: positive/HER2 negative metastatic
# NCT02958852: receptor+ metastatic breast
# NCT02959749: TKI
#
#           -  EGFR T790M positive
# NCT00718263: BCR-ABL a review
# NCT02804815: 2. HER2 positive
#
#                     3
# NCT02804815: negative/HER2 negative tumour
# NCT02804815: a HER2 positive tumour
# NCT02530125: v-myc avian myelocytomatosis
# NCT02530125: c-myc
#              testing prior
# NCT01757626: and MYCN-
# NCT02833766: stage
#
#           -  EGFR expression in
# NCT01933906: BCR-ABL positive chronic
# NCT02809573: lymphoma, ALK positive or
# NCT02342353: must have EGFR T790M
#              negative
# NCT02806050: staining), HER2 negative metastatic
# NCT02216617: non-metastatic
# NCT02324335: non-metastatic squamous
# NCT02369198: evidence of EGFR expression
#         in
# NCT02815397: c-myc breaks by
# NCT02811497: Positive and HER2 Negative Breast
# NCT02826512: advanced, HER2 negative breast
# NCT02805829: histologically confirmed HER2 positive advanced
# NCT02885727: non-metastatic pancreatic
# NCT02965417: ECD-EGFR mutation in
# NCT02965417: anti-EGFR mAbs
#
#                1
# NCT02965417: anti-EGFR mAb
# NCT02965417: anti-EGFR mAb treatment
# NCT02965417: anti-EGFR mAb to
# NCT02965950: in a metastatic deposit
# NCT02970682: confirmation of HER2 negative breast
# NCT02971748: or HER2 negative by
# NCT02971761: and HER2
#                   negative breast
# NCT02977364: c-MET positive patients
# NCT02977364: c-MET of patients
# NCT02987959: postovulation
#              methods
# NCT02987959: postovulation methods for
# NCT02990416: negative for BRAF or have
# NCT01884285: receptor and HER2 negative
#         advanced
# NCT02612194: non-metastatic bladder
# NCT00831324: cis-retinoic acid
# NCT01352091: Micro-metastasis
# NCT01556841: non-metastatic
# NCT01716949: oligo-metastases may
# NCT01728155: guidelines
#
#                -  MYCN non
# NCT01730677: positive for HER2 in tumor
# NCT01730677: anti-HER2 therapy in
# NCT01741038: anti-EGFR treatment
#
#           5
# NCT01741038: anti-EGFR therapy in
# NCT01846091: positive, HER2 negative breast
# NCT01846091: patients with HER2 positive breast
# NCT01846091: PR/HER2 negative breast
# NCT01869166: expression of EGFR in tumor
# NCT01869166: anti-EGFR using antibody
# NCT01873833: positive metastatic breast
# NCT01873833: cancer
#
#           -  HER2 overexpression of
# NCT01904123: positive metastatic
#              melanoma
# NCT01972373: fascia
#
#                -  metastatic lateral
# NCT01996098: NSCLC.
#
#           -  EGFR activating mutation
# NCT02046733: ULN
#
#           -  alkaline phosphatase
# NCT02059213: non-metastatic disease
# NCT02137356: non-metastatic rectal
# NCT02193152: defined as VEGFR1-
# NCT02205047: or postovulation methods
# NCT02264210: NSCLC.
#
#           -  EGFR activating mutation
# NCT02299141: target genes VEGFR1-
# NCT02299141: and FGFR1-
# NCT02311621: myelo-ablative therapy
# NCT02316457: as:
#
#                -  HER2 negative
# NCT02326285: 1xULN;
#
#                     -  alkaline phosphatase
# NCT02383030: HR+), HER2 negative breast
# NCT02383030: requirement for HER2 negative
#              disease
# NCT02383030: expression of HER2 by either
# NCT02389842: with
#              HER2 positive breast
# NCT02389842: or HER2 positive breast
# NCT02398773: ER+
#              metastatic site
# NCT02398773: HER2+) metastatic
#              disease
# NCT02501551: c-kit mutations
#
#           3
# NCT02535221: IHC) HER2 negative
#              breast
# NCT02561273: lymphoma
#              (ALK negative
# NCT02564900: cancer with HER2 overexpression that
# NCT02564900: adenocarcinoma with HER2 overexpression
#              that
# NCT02564900: cancer with HER2 low expression
# NCT02564900: tumor with HER2 expression other
# NCT02567253: Positive retroperitoneal lymph
# NCT02572453: with ALK
#              positivity defined
# NCT02576548: 3. HER2 Positive disease
# NCT02578797: non-metastatic castrate
# NCT02620280: 3. HER2 negative disease
# NCT02632201: expression of HER2 in immunohistochemical
# NCT02663297: patients with ALK negative CD30
# NCT02663297: CD30+ mycosis fungoides
# NCT02707393: BCR/ABL positive CML
# NCT02713984: or refractory HER2 positive cancer
# NCT02750215: therapy.
#
#           -  EGFR and ALK
# NCT02767063: BCR-ABL1
#              transcript positivity
# NCT02767063: BCR-ABLIS
# NCT02767063: BCR-ABL1 with BCR
# NCT02812693: c-KIT gene tested
# NCT02883049: BCR-ABL1)
# NCT02926196: Non-metastatic
# NCT02926196: and HER2 negative
# NCT02953184: non-metastatic
# NCT02992912: anti-EGFR
#                   therapy
# NCT02997228: involvement - alkaline phosphatase
# NCT02997501: Documented EGFR mutation positive
# NCT03002103: negative for HER2 by IHC
# NCT03006432: positive HER2 status is
# NCT03008109: NSCLC,EGFR mutation positive
# NCT03009240: postovulation methods
# NCT03009240: postovulation methods for
# NCT03012100: negative for HER2 as defined
# NCT03012100: below:
#
#                -  HER2 immunohistochemistry
# NCT03012100: amplified
#
#                -  HER2 IHC expression
# NCT03012100: done
#
#                -  HER2 IHC expression
# NCT03013504: intent
#
#           -  HER2 over
# NCT03017833: postovulation methods
# NCT03018080: negative metastatic breast
# NCT03018080: negative metastatic breast
# NCT03023358: lymphoma, ALK negative anapestic
# NCT03025035: for HER2 positive disease
# NCT03031691: anti-EGFR therapy
# NCT03033303: NB (MYCN-
# NCT03033303: and
#              MYCN-
# NCT03034200: 3-methoxytyramine
# NCT03036488: non-metastatic

# %%
existing_pending_trials = [ x["NCT_ID"] for x in db.CTGOV.find({"metadata.STATUS":"PENDING"}) ]
print len(existing_pending_trials)
# Out:
# 1729

# %%
previous_pending_trials = [ x["NCT_ID"] for x in db.CTGOV.find({"metadata.STATUS":"PENDING"}) ]
print len(previous_pending_trials)
# Out:
# 738

# %%
print set(existing_pending_trials).issuperset(set(previous_pending_trials))
# Out:
# True

# %%
difference = set(existing_pending_trials).difference(set(previous_pending_trials))
print len(difference)
# Out:
# 991

# %%
print len(difference)
difference_status = [ (x["NCT_ID"], x["metadata"]["STATUS"]) for x in db.CTGOV.find({"NCT_ID" : {"$in" : list(difference)}}) ]
print len(difference_status)
# Out:
# 991
# 991

# %%
client_prod = MongoClient("bioresearch-d1:23001")
db_prod = client_prod.WATSON

# %%
print db_prod.CTGOV.find({"metadata.STATUS":"PENDING"}).count()
# Out:
# 1729

# %%
difference_status = dict(difference_status)
count_new = 0
count_working = 0
for (nct_id, status) in difference_status.iteritems():
    if status == "NEW": count_new += 1
    if status == "WORKING": count_working += 1
        
print count_new
print count_working
# Out:
# 302
# 11

# %%
count = 0
for (nct_id, status) in difference_status.iteritems():
    if status in ["NEW", "WORKING"]:
        count += db_prod.CTGOV.update_one({"NCT_ID" : nct_id}, {"$set" : {"metadata.STATUS" : status}}).modified_count
    
print count
# Out:
# 313

# %%
cs = ClinicalStudy("NCT00924170")
cs.get()
print cs.get_title()
print cs.get_gender()
# Out:
# Phase II Trial of LMB-2, Fludarabine and Cyclophosphamide for Adult T-Cell Leukemia
# All

# %%
client = MongoClient("bioresearch-d1:23001")
db = client["WATSON"]

# %%
studies = db["CTGOV"].find({"metadata.DOWNLOAD_DATE" : {"$gt" : datetime.datetime(2017,3,27,0,0)}})
#studies = db["CTGOV"].find({"GENDER" : {"$exists" : False}})
print studies.count()
nct_ids = [ study["NCT_ID"] for study in studies ]
# Out:
# 130

# %%
study = db["CTGOV"].find_one({"NCT_ID" : 'TEST'})
print study["inclusion"]["GROUP_OPERATORS"] == []

for nct_id in nct_ids:
    print nct_id
    cs = ClinicalStudy(nct_id)
    cs.get()
    criteria = cs.get_raw_criteria()
    study = db["CTGOV"].find_one({"NCT_ID" : nct_id})
    inclusion = study["inclusion"]
    exclusion = study["exclusion"]
    
    inclusion["text"] = criteria["inclusion"]
    if inclusion.get("GROUP_OPERATORS") == []:
        inclusion["GROUP_OPERATORS"] = ["NONE"]
        
    if inclusion.get("variantGroups") == []:
        inclusion["variantGroups"] = [ {"OPERATOR" : "OR", "ID" : 1, "VARIANT_IDS" : []} ]
        
    exclusion["text"] = criteria["exclusion"]
    if exclusion.get("GROUP_OPERATORS") == []:
        exclusion["GROUP_OPERATORS"] = ["NONE"]
        
    if exclusion.get("variantGroups") == []:
        exclusion["variantGroups"] = [ {"OPERATOR" : "OR", "ID" : 1, "VARIANT_IDS" : []} ]
        
    db["CTGOV"].update_one({"NCT_ID" : nct_id}, {"$set" : {"inclusion" : inclusion, "exclusion" : exclusion}})
# Out:
# False
# NCT02581059
# NCT02078609
# NCT03075696
# NCT03073785
# NCT03076372
# NCT03076554
# NCT03079427
# NCT03079440
# NCT02955823
# NCT03072160
# NCT03072771
# NCT03072992
# NCT03072134
# NCT03075462
# NCT03076437
# NCT03074318
# NCT03075553
# NCT03075826
# NCT03077659
# NCT03077685
# NCT03078855
# NCT03079011
# NCT01444807
# NCT02063724
# NCT02259621
# NCT02302833
# NCT02564536
# NCT02765243
# NCT03049358
# NCT03071757
# NCT03071874
# NCT03072238
# NCT03073525
# NCT03074006
# NCT03074825
# NCT03075423
# NCT03075527
# NCT03077451
# NCT03077698
# NCT03078400
# NCT03088930
# NCT01806675
# NCT02372409
# NCT02681796
# NCT02706392
# NCT03000179
# NCT03050047
# NCT03071926
# NCT03072043
# NCT03076164
# NCT03077243
# NCT03078751
# NCT03079505
# NCT03079999
# NCT03080116
# NCT03080311
# NCT03080805
# NCT03080922
# NCT03080974
# NCT03081039
# NCT03081143
# NCT03081234
# NCT03081377
# NCT03081481
# NCT03081494
# NCT03081689
# NCT03081702
# NCT03081715
# NCT03081780
# NCT03081858
# NCT03081910
# NCT03081923
# NCT03082144
# NCT03082209
# NCT03082534
# NCT03083041
# NCT03083054
# NCT03083613
# NCT03083678
# NCT03083691
# NCT03083808
# NCT03083873
# NCT03084237
# NCT03084380
# NCT03084471
# NCT03084640
# NCT03084926
# NCT03084939
# NCT03085004
# NCT03085225
# NCT03085368
# NCT03085719
# NCT03085849
# NCT03085914
# NCT03085966
# NCT03086174
# NCT03086239
# NCT03086369
# NCT03086538
# NCT03086616
# NCT03086642
# NCT03086681
# NCT03086785
# NCT03086954
# NCT03086993
# NCT03087019
# NCT03087071
# NCT03087448
# NCT03087591
# NCT03087760
# NCT03087864
# NCT03087903
# NCT03088059
# NCT03088124
# NCT03088527
# NCT03088540
# NCT03088709
# NCT03088813
# NCT03088878
# NCT03089203
# NCT03089554
# NCT03089606
# NCT03089645
# NCT03089918
# NCT03090165
# NCT03090412
# NCT03077828
# NCT01676753
# NCT03074513
# NCT03088176

# %%
with open("/Users/singhv/Desktop/genders.txt", "wb") as f:
    for nct_id in nct_ids:
        cs = ClinicalStudy(nct_id)
        cs.get()
        print cs.get_gender()
        db["CTGOV"].update_one({"NCT_ID" : nct_id}, {"$set" : {"GENDER" : cs.get_gender()}})
        f.write(nct_id + "\t" + cs.get_gender() + "\n")
# Out:
# All
# All
# All
# All
# All
# All
# All
# All
# All
# All
# All
# Female
# All
# Female
# All
# All
# All
# All
# Male
# All
# All
# Female
# All
# All
# Female
# All
# All
# All
# All
# All
# All
# All
# Male
# Female
# All
# All
# All
# All
# All
# All
# Female
# All
# Female
# All
# All
# All
# All
# All
# All
# Female
# All
# All
# All
# All
# All
# All
# Male
# All
# All
# All
# All
# All
# All
# All
# All
# Male
# All
# All
# Female
# All
# All
# All
# All
# Male
# All
# All
# All
# All
# All
# All
# All
# All
# All
# All
# Female
# All
# All
# All
# All
# All
# All
# All
# Female
# All
# All
# All
# Male
# All
# All
# All
# All
# All
# All
# Female
# Female
# All
# All
# All
# All
# All
# All
# All
# All
# Male
# All
# Male
# All
# Female
# All
# All
# All
# All
# All
# Male
# All
# All
# All
# All
# All
# All
